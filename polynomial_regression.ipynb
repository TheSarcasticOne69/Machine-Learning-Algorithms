# %% [markdown]
# <a href="https://colab.research.google.com/github/TheSarcasticOne69/Machine-Learning-Algorithms/blob/main/polynomial_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Polynomial Regression
# Polynomial Regression is a form of regression analysis where the relationship between the independent variable
# 𝑥
# x and the dependent variable
# 𝑦
# y is modeled as an
# 𝑛
# nth degree polynomial.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Step 1: Load the data
data = pd.read_csv("polynomial-data.csv")
X = data[['X']].values
y = data['Y'].values

# Step 2: Transform features to polynomial features
degree = 2  # You can change this to 3, 4, etc.
poly = PolynomialFeatures(degree=degree)
X_poly = poly.fit_transform(X)

# Step 3: Fit the model
model = LinearRegression()
model.fit(X_poly, y)

# Step 4: Predict
y_pred = model.predict(X_poly)

# Step 5: Visualization
plt.scatter(X, y, color='blue', label='Original Data')
plt.plot(X, y_pred, color='red', label=f'Polynomial Regression (degree={degree})')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Regression Example')
plt.legend()
plt.grid(True)
plt.show()

# Step 6: Print coefficients
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [0.         0.38796159 0.99423182]
# Intercept: -4.66223775510241

# %%
data.head()
# Out:
#    X      Y
# 0  1   0.24
# 1  2  -0.22
# 2  3   2.42
# 3  4  11.72
# 4  5  17.08
